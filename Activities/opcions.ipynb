# %% [markdown]
# # OPCIONS CODI LABERINT MINECRAFT
#
# Benvinguts al taller de Minecraft! Aquí teniu les opcions disponibles per el codi del joc del laberint.
#
# ## Com trobar les opcions per cada pregunta?
#
# - Cada pregunta té número únic.
# - A sota de cada pregunta, haureu d'enganxar el codi corresponent a l'opció que hagueu escollit.
# - Assegureu-vos de no modificar cap altra part del codi per evitar errors.
# - **Els reptes no tenen opcions**.
#
#
# > **Nota:** Per possibles errors a l'hora de copiar i enganxar, demaneu ajuda!

# %% [markdown]
# ## Pregunta **1**
#
# ### **A**:

# %%
mc.player.setTilePos(1, 4, 1)

# %% [markdown]
# ### **B**:

# %%
mc.player.move(1, 4, 1)

# %% [markdown]
# ### **C**:

# %%
mc.player.teleport(1, 4, 1)

# %% [markdown]
# ### **D**:

# %%
mc.setTilePos(1, 4, 1)

# %% [markdown]
# ## Pregunta **2**
#
# ### **A**:

# %%
def chat_events():
    chat_events = mc.events.pollChatPosts()

    for e in chat_events:
        missatge = e.message

# %% [markdown]
# ### **B**:

# %%
def chat_events():
    chat_events = mc.events.pollChatPosts()

    if block.DIAMOND_BLOCK == block.DIAMOND_BLOCK:
        mc.postToChat("missatge")

# %% [markdown]
# ### **C**:

# %%
def chat_events():
    chat_events = mc.events.pollChatPosts()

    for e in chat_events:
        return e.message

# %% [markdown]
# ## Pregunta **3**
#
# Fórmula per calcular la distància entre dos punts en l'espai 3D:
#
# $$
# d(p_1, p_2) = \sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2 + (z_2 - z_1)^2}
# $$
#
#
# ### **A**:

# %%
def calcular_distancia(pos1, pos2):
    distancia = math.sqrt((pos1 - pos2) ** 2 + (pos1 - pos2) ** 2)
    return distancia

# %% [markdown]
# ### **B**:

# %%
def calcular_distancia(pos1, pos2):
    distancia = math.sqrt((pos1.x - pos2.x) ** 2 + (pos1.y - pos2.y) ** 2 + (pos1.z - pos2.z) ** 2)
    return distancia

# %% [markdown]
# ### **C**:

# %%
def calcular_distancia(pos1, pos2):
    distancia = math.sqrt((pos1.x - pos2.x) ** 2 + (pos1.y - pos2.y) ** 2 + (pos1.z - pos2.z) ** 2)

# %% [markdown]
# ## Pregunta **4**

# %% [markdown]
# ### **A**:

# %%
# CODI X
if diff_x > 0:
    direccio = "est"
else:
    direccio = "oest"


# CODI Z
if diff_z > 0:
    direccio = "sud"
else:
    direccio = "nord"

# %% [markdown]
# ### **B**:

# %%
# CODI X
if diff_x > 0:
    direccio = "sud"
else:
    direccio = "nord"


# CODI Z
if diff_z > 0:
    direccio = "est"
else:
    direccio = "oest"

# %% [markdown]
# ## Pregunta **5**
#
# En aquest cas només proporcionem la base del codi. Haureu de modificar el codi per tal que funcioni correctament.
#
# ### **A**:

# %%
posicio_jugador = mc.player.getTilePos()
distancia = posicio_jugador, posició_objectiu
direccio = posicio_jugador, posició_objectiu
mc.postToChat(f"Distancia als blocs de colors: {int(distancia)} blocs cap al {direccio}")

# %% [markdown]
# ### **B**:

# %%
posicio_jugador = mc.playerPos()
distancia = calcular_distancia(posicio_jugador)
direccio = obtenir_direccio(posicio_jugador)
mc.postToChat(f"Distancia als blocs de colors: {int(distancia)} blocs cap al {direccio}")

# %% [markdown]
# ### **C**:

# %%
posicio_jugador = mc.player.getTilePos()
distancia = calcular_distancia(posicio_jugador_jugador)
direccio = calcular_distancia(posicio_objectiu)
mc.postToChat(f"Distancia als blocs de colors: {int(distancia)} blocs cap al {direccio}")

# %% [markdown]
# ### **D**:

# %%
posicio_jugador = mc.player.getTilePos()
distancia = calcular_distancia(posicio_jugador, posició_objectiu)
direccio = obtenir_direccio(posicio_jugador, posició_objectiu)
mc.postToChat(f"Distancia als blocs de colors: {int(distancia)} blocs cap al {direccio}")

# %% [markdown]
# ## Pregunta **6**
#
# ### **A**:

# %%
if pos.x == 7 and pos.y == 4 and pos.z == 67:
    mc.setBlock(11, 5, 67, block.AIR.id)
    mc.setBlock(11, 4, 67, block.AIR.id)
else pos.x == 28 and pos.y == 4 and pos.z == 67:
    start = False

# %% [markdown]
# ### **B**:

# %%
if pos.x == 7 and pos.y == 4 and pos.z == 67:
    mc.setBlock(11, 5, 67, block.AIR.id)
    mc.setBlock(11, 4, 67, block.AIR.id)
elif pos.x == 28 and pos.y == 4 and pos.z == 67:
    start = False

# %% [markdown]
# ### **C**:

# %%
if pos.x == 7 and pos.y == 4 and pos.z == 67:
    bloc1 = AIR
    bloc2 = AIR
elif pos.x == 28 and pos.y == 4 and pos.z == 67:
    start = False

# %% [markdown]
# ### **D**:

# %%
if pos.x == 7 and pos.y == 4 and pos.z == 67:
    mc.setBlock(11, 5, 67, block.AIR.id)
    mc.setBlock(11, 4, 67, block.AIR.id)
elif pos.x == 28 and pos.y == 4 and pos.z == 67:
    start = True

# %% [markdown]
# ### **E**:

# %%
if posicio = (7, 4, 67):
    mc.setBlock(11, 5, 67, block.AIR.id)
    mc.setBlock(11, 4, 67, block.AIR.id)
elif posicio == (28, 4, 67):
    start = False
